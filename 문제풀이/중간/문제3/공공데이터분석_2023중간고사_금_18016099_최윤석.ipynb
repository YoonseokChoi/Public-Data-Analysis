# %%
# 사용할 패키지를 import합니다
import sys
print('python', sys.version)

import numpy as np
print('numpy', np.__version__)

import pandas as pd
print('pandas', pd.__version__)

import matplotlib as mpl
print('matplotlib', mpl.__version__)

import matplotlib.pyplot as plt
plt.rc("font", family="Malgun Gothic") # window

import seaborn as sns
print('seaborn', sns.__version__)

# 결과 확인을 용이하게 하기 위한 코드
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# # 경고 메시지는 출력되지 않게 합니다.
# import warnings
# warnings.filterwarnings("ignore")
# Out:
# python 3.11.5 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:26:23) [MSC v.1916 64 bit (AMD64)]
# numpy 1.24.3
# pandas 2.0.3
# matplotlib 3.7.2
# seaborn 0.12.2

# %% [markdown]
# # 문제1
# * df1의 'a' column이 'y'인 행만 골라서, 결측치를 -1 으로 채운 df1a을 출력하시오

# %%
df1=pd.DataFrame({'a':list('yynnynyy'), 'b':[1,2,np.nan,4,np.nan,6,np.nan,8], 'c':[1,2,3,4,5,6,np.nan,np.nan]})
print("## 주어진 데이터")
df1

## 코드 작성 ##
df1a = df1.loc[df1['a']=='y'].fillna(-1)
print("## 코딩 결과")
df1a
# Out:
# ## 주어진 데이터
#    a    b    c
# 0  y  1.0  1.0
# 1  y  2.0  2.0
# 2  n  NaN  3.0
# 3  n  4.0  4.0
# 4  y  NaN  5.0
# 5  n  6.0  6.0
# 6  y  NaN  NaN
# 7  y  8.0  NaN
# ## 코딩 결과
#    a    b    c
# 0  y  1.0  1.0
# 1  y  2.0  2.0
# 4  y -1.0  5.0
# 6  y -1.0 -1.0
# 7  y  8.0 -1.0

# %% [markdown]
# # 문제2
# * df2의 'a' column에서 숫자로만 이루어진 값들의 합을 구하시오

# %%
df2=pd.DataFrame({'a':np.random.randint(1,5,size=10).astype(str)})
df2['a']=[df2.loc[x,'a']+'_' if x in [3,4,6,8] else df2.loc[x,'a'] for x in range(10)]
df2.loc[2,'a']=np.nan
df2.loc[7,'a']=np.nan
print("## 주어진 데이터")
df2

## 코드작성
def f2(x):
    if x!=x:
        return 0
    elif '_' in x:
        return 0
    else:
        return int(x)

df2['a_'] = df2['a'].map(f2)    
s1 = np.sum(df2['a_'])

print("## 코딩 결과")
s1
# Out:
# ## 주어진 데이터
#      a
# 0    2
# 1    2
# 2  NaN
# 3   2_
# 4   3_
# 5    1
# 6   1_
# 7  NaN
# 8   3_
# 9    2
# ## 코딩 결과
# 7

# %% [markdown]
# # 문제3
# * df3의 column p1에 가격이 dollar와 won으로 표시되어있다. column p2를 만들어 새로운 가격을 넣으시오
# * 조건1) dollar의 경우 dollar제거후 1000을 곱한 값을, won인 경우 won을 제거한 값을 그대로 넣으시오
# * 조건2) dtypes를 확인했을 때 p2 column의 dtype이 int가 되게 하시오

# %%
df3=pd.DataFrame({'p1':['1dollar','2dollar','3000won','4dollar','5dollar','6000won','7dollar']})
print("## 주어진 데이터")
df3

 ## 코드작성
def f3(x):
    if x!=x:
        return np.nan
    if 'dollar' in x:
        x1 = x.split('d')
        return int(x1[0])*1000
    if 'won' in x:
        x2 = x.replace('won','')
        return int(x2)

df3['p2'] = df3['p1'].map(f3)

print("## 코딩 결과")
df3
df3.dtypes
# Out:
# ## 주어진 데이터
#         p1
# 0  1dollar
# 1  2dollar
# 2  3000won
# 3  4dollar
# 4  5dollar
# 5  6000won
# 6  7dollar
# ## 코딩 결과
#         p1    p2
# 0  1dollar  1000
# 1  2dollar  2000
# 2  3000won  3000
# 3  4dollar  4000
# 4  5dollar  5000
# 5  6000won  6000
# 6  7dollar  7000
# p1    object
# p2     int64
# dtype: object

# %% [markdown]
# # 문제4
# * dataframe df4에서 c1 별 v1 값 중 짝수의 평균을 구하시오
# * 조건1) apply를 사용하시오

# %%
df4=pd.DataFrame({'c1':list('aaaabbaaabbbabb'), 'v1':[ 3, 12, 13, 7, 6, 9, 10, 2, 1, 14, 0, 4, 5, 8, 11]})
print("## 주어진 데이터")
df4

## 코드작성 ##
def f4(x):
    x1 = x.loc[x%2==0]
    return x1.mean()
    
df4.groupby(['c1'])['v1'].apply(f4)

print("## 코딩 결과")
# sr4a
# Out:
# ## 주어진 데이터
#    c1  v1
# 0   a   3
# 1   a  12
# 2   a  13
# 3   a   7
# 4   b   6
# 5   b   9
# 6   a  10
# 7   a   2
# 8   a   1
# 9   b  14
# 10  b   0
# 11  b   4
# 12  a   5
# 13  b   8
# 14  b  11
# c1
# a    8.0
# b    6.4
# Name: v1, dtype: float64
# ## 코딩 결과

# %% [markdown]
# # 문제5
# * dataframe df_last에서 "전용면적 별" "지역 별" 평당분양가격의 "최대값"을 df5에 담아 출력하시오
# * 조건1) groupby를 사용하시오

# %%
def get_area_type(x):
    x2=x.replace("전용면적", "").replace("초과", "~").replace("이하", "").replace(" ", "")
    return x2

df_last = pd.read_csv("data/전국평균 분양가격 (2015년10월~2019년12월).csv", encoding="cp949")
df_last["분양가격"] = pd.to_numeric(df_last["분양가격(㎡)"], errors='coerce')
df_last["평당분양가격"] = df_last["분양가격"] * 3.3
df_last["전용면적"] = df_last["규모구분"].map(get_area_type)
df_last=df_last.drop(columns=['규모구분','분양가격(㎡)','분양가격'], errors='ignore') # error raise 방지
df_last=df_last.loc[df_last['평당분양가격'].notnull()]
print("## 주어진 데이터")
df_last

## 코드작성
df5 = df_last.groupby(['지역명','전용면적'])['평당분양가격'].max().unstack()
print("## 코딩 결과")
df5
# Out:
# ## 주어진 데이터
#      지역명    연도   월   평당분양가격      전용면적
# 0     서울  2015  10  19275.3        전체
# 1     서울  2015  10  18651.6       60㎡
# 2     서울  2015  10  19410.6   60㎡~85㎡
# 3     서울  2015  10  18879.3  85㎡~102㎡
# 4     서울  2015  10  19400.7     102㎡~
# ...   ..   ...  ..      ...       ...
# 4327  경남  2019  12  10114.5   60㎡~85㎡
# 4328  경남  2019  12  10715.1  85㎡~102㎡
# 4330  제주  2019  12  12810.6        전체
# 4332  제주  2019  12  12863.4   60㎡~85㎡
# 4334  제주  2019  12  11883.3     102㎡~
#
# [3957 rows x 5 columns]
# ## 코딩 결과
# 전용면적    102㎡~      60㎡  60㎡~85㎡  85㎡~102㎡       전체
# 지역명
# 강원    11873.4   8494.2   8322.6   10985.7   8362.2
# 경기    18711.0  16272.3  15018.3   17945.4  14952.3
# 경남    14199.9   9692.1  10480.8   13143.9  10589.7
# 경북    11408.1   8507.4   9560.1    9461.1   9616.2
# 광주    16107.3  12955.8  12711.6    9504.0  12658.8
# 대구    17021.4  14401.2  14470.5   14922.6  14536.5
# 대전    16094.1  11916.3  12134.1   10121.1  12173.7
# 부산    15255.9  13104.3  13440.9   15123.9  13497.0
# 서울    29663.7  27327.3  28340.4   42002.4  26730.0
# 세종    12972.3  10111.2  11203.5   11583.0  11411.4
# 울산    10543.5  11216.7  11860.2    9738.3  11820.6
# 인천    17120.4  13176.9  13163.7   13137.3  13206.6
# 전남    10074.9   8345.7   8296.2    8669.1   8292.9
# 전북     9405.0   8797.8   8679.0   10071.6   8679.0
# 제주    15840.0  18024.6  12863.4   15869.7  12952.5
# 충남     9368.7   8566.8   8853.9   10563.3   8916.6
# 충북     9150.9   7748.4   8698.8    9421.5   8698.8

# %% [markdown]
# # 문제6
# * 2018년에 집값의 변동성이 가장 큰 도시와 가장 작은 도시를 출력하시오
# * 조건1) 변동성은 std 함수를 사용하여 측정하시오
# * 주의1) 2018년 데이터만 분석

# %%
def get_area_type(x):
    x2=x.replace("전용면적", "").replace("초과", "~").replace("이하", "").replace(" ", "")
    return x2

df_last = pd.read_csv("data/전국평균 분양가격 (2015년10월~2019년12월).csv", encoding="cp949")
df_last["분양가격"] = pd.to_numeric(df_last["분양가격(㎡)"], errors='coerce')
df_last["평당분양가격"] = df_last["분양가격"] * 3.3
df_last["전용면적"] = df_last["규모구분"].map(get_area_type)
df_last=df_last.drop(columns=['규모구분','분양가격(㎡)','분양가격'], errors='ignore') # error raise 방지
df_last=df_last.loc[df_last['평당분양가격'].notnull()]
print("## 주어진 데이터")
df_last

## 코드작성
dfa = df_last.loc[df_last['연도']==2018]
dfs = dfa.groupby(['지역명'])['평당분양가격'].std().to_frame().sort_values(by='평당분양가격')
dfs

small_std_city = dfs.index[0]
large_std_city = dfs.index[-1]

print("## 코딩 결과")
print('변동성이 가장 큰 도시:', large_std_city)
print('변동성이 가장 작은 도시:', small_std_city)
# Out:
# ## 주어진 데이터
#      지역명    연도   월   평당분양가격      전용면적
# 0     서울  2015  10  19275.3        전체
# 1     서울  2015  10  18651.6       60㎡
# 2     서울  2015  10  19410.6   60㎡~85㎡
# 3     서울  2015  10  18879.3  85㎡~102㎡
# 4     서울  2015  10  19400.7     102㎡~
# ...   ..   ...  ..      ...       ...
# 4327  경남  2019  12  10114.5   60㎡~85㎡
# 4328  경남  2019  12  10715.1  85㎡~102㎡
# 4330  제주  2019  12  12810.6        전체
# 4332  제주  2019  12  12863.4   60㎡~85㎡
# 4334  제주  2019  12  11883.3     102㎡~
#
# [3957 rows x 5 columns]
#           평당분양가격
# 지역명
# 세종    166.723621
# 울산    347.328465
# 충남    405.063755
# 전남    418.521337
# 경북    508.413174
# 경남    545.938056
# 부산    622.911101
# 충북    646.657440
# 전북    720.390658
# 광주    720.877481
# 강원    742.016586
# 대구    962.011659
# 경기   1099.149797
# 인천   1501.907083
# 서울   1638.037426
# 대전   2114.894675
# 제주   2442.893636
# ## 코딩 결과
# 변동성이 가장 큰 도시: 제주
# 변동성이 가장 작은 도시: 세종

# %% [markdown]
# # 문제7
# * df_last에서 "지역 별" 평당분양가격의 최대값을 bargraph로 나타내시오
# * 조건1) pivot_table 과 pandas plot 함수를 사용하시오

# %%
def get_area_type(x):
    x2=x.replace("전용면적", "").replace("초과", "~").replace("이하", "").replace(" ", "")
    return x2

df_last = pd.read_csv("data/전국평균 분양가격 (2015년10월~2019년12월).csv", encoding="cp949")
df_last["분양가격"] = pd.to_numeric(df_last["분양가격(㎡)"], errors='coerce')
df_last["평당분양가격"] = df_last["분양가격"] * 3.3
df_last["전용면적"] = df_last["규모구분"].map(get_area_type)
df_last=df_last.drop(columns=['규모구분','분양가격(㎡)','분양가격'], errors='ignore') # error raise 방지
df_last=df_last.loc[df_last['평당분양가격'].notnull()]
print("## 주어진 데이터")
df_last

## 코드작성
dfmax = df_last.pivot_table(index='지역명',values='평당분양가격', aggfunc=np.max)
_=dfmax.plot.bar()

print("## 코딩 결과")
# Out:
# ## 주어진 데이터
#      지역명    연도   월   평당분양가격      전용면적
# 0     서울  2015  10  19275.3        전체
# 1     서울  2015  10  18651.6       60㎡
# 2     서울  2015  10  19410.6   60㎡~85㎡
# 3     서울  2015  10  18879.3  85㎡~102㎡
# 4     서울  2015  10  19400.7     102㎡~
# ...   ..   ...  ..      ...       ...
# 4327  경남  2019  12  10114.5   60㎡~85㎡
# 4328  경남  2019  12  10715.1  85㎡~102㎡
# 4330  제주  2019  12  12810.6        전체
# 4332  제주  2019  12  12863.4   60㎡~85㎡
# 4334  제주  2019  12  11883.3     102㎡~
#
# [3957 rows x 5 columns]
# ## 코딩 결과

# %% [markdown]
# # 문제8~9
# * dataframe df8에서 "group별" "year별" score의 평균을 아래 그림과 같이 두 axes에 bar plot으로 나타내시오
# * 조건1) pandas plot을 사용하여 ax1 axes에 나타내시오
# * 조건2) seaborn plot을 사용하여 ax2 axes에 나타내시오 (ci는 default값 사용)

# %%
df8=pd.DataFrame({'year':['2021','2022','2023']*30, 'group':['a','b']*45, 'score':np.arange(90)})
print("## 주어진 데이터")
df8

fig=plt.figure(figsize=(8, 3), dpi=150)
ax1, ax2=fig.subplots(1,2)

## 코드작성
dfm =df8.groupby(['year','group'])['score'].mean().unstack()
_=dfm.plot.bar(ax=ax1)

_=sns.barplot(data=df8, x='year', y='score', hue='group', estimator=np.mean,ax=ax2)

fig.tight_layout()
print("## 코딩 결과")
# Out:
# ## 주어진 데이터
#     year group  score
# 0   2021     a      0
# 1   2022     b      1
# 2   2023     a      2
# 3   2021     b      3
# 4   2022     a      4
# ..   ...   ...    ...
# 85  2022     b     85
# 86  2023     a     86
# 87  2021     b     87
# 88  2022     a     88
# 89  2023     b     89
#
# [90 rows x 3 columns]
# ## 코딩 결과

# %% [markdown]
# # 문제10
# * dataframe df10에서 year 별, group 별 score 값을 아래와 같은 boxplot으로 나타내시오
# * 조건1) seaborn plot을 사용하시오
# * 조건2) 주어진 ax1에 나타내시오

# %%
df10=pd.DataFrame({'year':['2021']*100+['2022']*100+['2023']*100, 'group':(['a']*50+['b']*50)*3, 'score':np.arange(300)})
print("## 주어진 데이터")
df10

fig=plt.figure(figsize=(6, 3), dpi=100)
ax1=fig.subplots()

## 코드작성
_=sns.boxplot(data=df10, x='year', y='score', hue='group', ax=ax1)
print("## 코딩 결과")
# Out:
# ## 주어진 데이터
#      year group  score
# 0    2021     a      0
# 1    2021     a      1
# 2    2021     a      2
# 3    2021     a      3
# 4    2021     a      4
# ..    ...   ...    ...
# 295  2023     b    295
# 296  2023     b    296
# 297  2023     b    297
# 298  2023     b    298
# 299  2023     b    299
#
# [300 rows x 3 columns]
# ## 코딩 결과

# %% [markdown]
# # 문제11
# * df11a과 df11b를 'key'로 merge한 df11c를 아래와 같이 출력하시오

# %%
df11a = pd.DataFrame({'key': ['a', 'b', 'c', 'd'], 'v1': [1, 2, 3, 4], 'v2': [1, 2, 3, 4]})
df11b = pd.DataFrame({'key': ['e', 'c', 'b', 'a'], 'v3': [4, 3, 2, 1], 'v4': [4, 3, 2, 1]})
print("## 주어진 데이터")
df11a
df11b

## 코드작성
df11c = pd.merge(df11a,df11b, on='key', how='left')
df11c
# Out:
# ## 주어진 데이터
#   key  v1  v2
# 0   a   1   1
# 1   b   2   2
# 2   c   3   3
# 3   d   4   4
#   key  v3  v4
# 0   e   4   4
# 1   c   3   3
# 2   b   2   2
# 3   a   1   1
#   key  v1  v2   v3   v4
# 0   a   1   1  1.0  1.0
# 1   b   2   2  2.0  2.0
# 2   c   3   3  3.0  3.0
# 3   d   4   4  NaN  NaN

# %% [markdown]
# # 문제12
# * 아래 주어진 세 개의 series c1, c2, c3를 연결하여 100행 3열의 dataframe을 만들고, boxplot을 그리시오
# * 주의1) random data를 사용하기때문에 결과 그림이 조금씩은 다를수 있음

# %%
c1=pd.Series(np.random.normal(50,1,size=100), name='c1')
c2=pd.Series(np.random.normal(70,1,size=100), name='c2')
c3=pd.Series(np.random.normal(60,1,size=100), name='c3')
print("## 주어진 데이터")
c1.head(3)
c2.head(3)
c3.head(3)

## 코드작성
c123 = pd.concat((c1,c2,c3),axis=1)
c123

_=c123.plot.box()
print("## 코딩 결과")
# Out:
# ## 주어진 데이터
# 0    51.262146
# 1    49.001019
# 2    50.059389
# Name: c1, dtype: float64
# 0    68.754753
# 1    68.605134
# 2    70.999757
# Name: c2, dtype: float64
# 0    59.421543
# 1    58.618474
# 2    59.366372
# Name: c3, dtype: float64
#            c1         c2         c3
# 0   51.262146  68.754753  59.421543
# 1   49.001019  68.605134  58.618474
# 2   50.059389  70.999757  59.366372
# 3   48.610186  69.072383  59.478931
# 4   48.970748  73.105890  59.397002
# ..        ...        ...        ...
# 95  48.718537  70.895157  58.576025
# 96  49.127203  70.886112  60.907531
# 97  49.212992  69.957981  58.967821
# 98  50.485308  68.999551  61.493867
# 99  50.759701  70.730887  60.165369
#
# [100 rows x 3 columns]
# ## 코딩 결과

# %% [markdown]
# # 문제13
# * df13의 column a의 네 개의 숫자 중에 세번째 있는 숫자만을 가지고 column b를 만드시오

# %%
df13=pd.DataFrame({'a':['1_51_1_2','1_41_10_4','1_31_100_5','1_22_1000_6']})
print("## 주어진 데이터")
df13

## 코드작성
def f13(x):
    if x!=x:
        return np.nan
    else:
        x1=x.split('_')
        return x1[2]
    
df13['b'] = df13['a'].map(f13)   
print("## 코딩 결과")
df13
# Out:
# ## 주어진 데이터
#              a
# 0     1_51_1_2
# 1    1_41_10_4
# 2   1_31_100_5
# 3  1_22_1000_6
# ## 코딩 결과
#              a     b
# 0     1_51_1_2     1
# 1    1_41_10_4    10
# 2   1_31_100_5   100
# 3  1_22_1000_6  1000

# %% [markdown]
# # 문제14
# * dataframe df_last에서 "전용면적 별" 평당분양가격의 "최대값"을 아래 그림과 같이 barplot으로 그리시오
# * 조건1) seaborn plot을 사용하시오
# * 조건2) 최대값이 큰 순서로 전용면적(x축)을 sorting 하시오
# * 조건3) 주어진 ax1에 나타내시오
# * 조건4) ci는 default 값 사용

# %%
def get_area_type(x):
    x2=x.replace("전용면적", "").replace("초과", "~").replace("이하", "").replace(" ", "")
    return x2

df_last = pd.read_csv("data/전국평균 분양가격 (2015년10월~2019년12월).csv", encoding="cp949")
df_last["분양가격"] = pd.to_numeric(df_last["분양가격(㎡)"], errors='coerce')
df_last["평당분양가격"] = df_last["분양가격"] * 3.3
df_last["전용면적"] = df_last["규모구분"].map(get_area_type)
df_last=df_last.drop(columns=['규모구분','분양가격(㎡)','분양가격'], errors='ignore') # error raise 방지
df_last=df_last.loc[df_last['평당분양가격'].notnull()]
print("## 주어진 데이터")
df_last

fig=plt.figure(figsize=(5, 3), dpi=150)
ax1=fig.subplots()

## 코드작성
dfmax=df_last.groupby(['전용면적'])['평당분양가격'].max().sort_values(ascending=False).to_frame()
dfmax

_=sns.barplot(data=df_last, x='전용면적', y='평당분양가격', estimator=np.max, order=dfmax.index,ax=ax1)

print("## 코딩 결과")
# Out:
# ## 주어진 데이터
#      지역명    연도   월   평당분양가격      전용면적
# 0     서울  2015  10  19275.3        전체
# 1     서울  2015  10  18651.6       60㎡
# 2     서울  2015  10  19410.6   60㎡~85㎡
# 3     서울  2015  10  18879.3  85㎡~102㎡
# 4     서울  2015  10  19400.7     102㎡~
# ...   ..   ...  ..      ...       ...
# 4327  경남  2019  12  10114.5   60㎡~85㎡
# 4328  경남  2019  12  10715.1  85㎡~102㎡
# 4330  제주  2019  12  12810.6        전체
# 4332  제주  2019  12  12863.4   60㎡~85㎡
# 4334  제주  2019  12  11883.3     102㎡~
#
# [3957 rows x 5 columns]
#            평당분양가격
# 전용면적
# 85㎡~102㎡  42002.4
# 102㎡~     29663.7
# 60㎡~85㎡   28340.4
# 60㎡       27327.3
# 전체        26730.0
# ## 코딩 결과
